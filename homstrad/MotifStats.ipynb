# %%
# %load_ext autoreload
# %autoreload 2

from __future__ import division

import os
import os.path
import math
import pickle
import multiprocessing
import collections

import numpy as np
import Bio.ExPASy.Prosite as BEP
import praline
import praline.container
import mapraline.component
import mapraline.prosite
from praline.core import *

# %%
INPUT_DIR = 'output/'
TRACK_ID_BASE = "mapraline.track.PrositePatternAnnotation"
FMT_TRACK_ID = "{0}_{1}"
ALPHABET = mapraline.ALPHABET_PROSITE
PROSITE_PATH = '/Users/maurits/Downloads/prosite.dat'

# %%
def read_patterns(path):
    patterns = []

    with file(path, 'r') as fi:
        for record in BEP.parse(fi):
            pattern = record.pattern.rstrip('.')
            if len(pattern):
                patterns.append(pattern)
    
    return patterns

# %%
# Read all patterns from our local prosite db.
patterns = read_patterns(PROSITE_PATH)

# Read all HOMSTRAD alignments.
alignments = []
for path, dirnames, filenames in os.walk(INPUT_DIR):
    for filename in filenames:
        if not filename.endswith('.aln'):
            continue
            
        path = os.path.join(INPUT_DIR, filename)
        try:
            alignment = praline.load_alignment_fasta(path, praline.container.ALPHABET_AA)
        except praline.AlphabetError:
            continue
                    
        alignments.append(alignment)

# %%
regexes = []
for pattern in patterns:
    re = mapraline.prosite.pattern_to_re(pattern)
    regexes.append((pattern, re))

# %%
def get_sequences(alignment):
    seqs = []
    for seq in alignment.items:
        track = seq.get_track(praline.container.TRACK_ID_INPUT)
        
        indices = track.values
        sym_list = []
        for n in xrange(indices.shape[0]):
            sym_list.append(track.alphabet.index_to_symbol(indices[n]))
        seqs.append("".join(sym_list))
    
    return seqs

# %%
seq_sets = [get_sequences(aln) for aln in alignments]

# %%
pattern_to_match_sets = {}
for pattern, regex in regexes:
    match_sets = []
    for seq_set in seq_sets:
        match_set = []
        for seq in seq_set:
            matches = list(regex.finditer(seq, overlapped=True))
            match_set.append(matches)
        match_sets.append(match_set)
    pattern_to_match_sets[pattern] = match_sets

# %%
count_motifs = 0
count_seqs = sum(len(aln.items) for aln in alignments)
count_alns = len(alignments)
for pattern, match_sets in pattern_to_match_sets.iteritems():
    for match_set in match_sets:
        for matches in match_set:
            count_motifs += len(matches)

# %%
count_motifs, count_seqs, count_alns
# Out:
# (34568, 3102, 974)

# %%
count_per_aln = collections.defaultdict(lambda: 0)
count_per_seq = collections.defaultdict(lambda: 0)
for pattern, match_sets in pattern_to_match_sets.iteritems():
    for i, match_set in enumerate(match_sets):
        for j, matches in enumerate(match_set):
            count_per_aln[i] += len(matches)
            count_per_seq[i, j] += len(matches)

# %%
a = np.array(count_per_aln.values())
b = np.array(count_per_seq.values())

# %%
a.min(), a.max(), a.mean()
# Out:
# (0, 619, 35.49075975359343)

# %%
b.min(), b.max(), b.mean()
# Out:
# (0, 69, 11.143778207607994)

# %%
def find_repeats(matches, adjacency_window=1):
    repeat_sets = []
    cur_repeat_set = []
    
    for match in matches:
        start = match.start()
        end = match.end()
        
        if not len(cur_repeat_set):
            cur_repeat_set = [match]
        else:
            prev_match = cur_repeat_set[-1]
            prev_end = prev_match.end()
            
            # Match falls within the adjacency window.
            if (prev_end + adjacency_window) >= start:
                cur_repeat_set.append(match)
            else:
                repeat_sets.append(cur_repeat_set)
                cur_repeat_set = [match]
    
    if len(cur_repeat_set):
        repeat_sets.append(cur_repeat_set)
    
    return repeat_sets

# %%
pat_aln_seq_to_repeat_matches = {}
for pattern, match_sets in pattern_to_match_sets.iteritems():
    for i, match_set in enumerate(match_sets):
        for j, matches in enumerate(match_set):
            pat_aln_seq_to_repeat_matches[pattern, i, j] = find_repeats(matches, 5)

# %%
repeat_counts = []
for (pat, i, j), repeat_set in pat_aln_seq_to_repeat_matches.iteritems():
    repeats = [len(x) for x in repeat_set if len(x) > 1]
    if repeats:
        print pat, repeats
        repeat_counts.extend(repeats)
# Out:
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2, 2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2, 2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2, 3]
# N-{P}-[ST]-{P} [2, 2, 2]
# N-{P}-[ST]-{P} [2, 2, 2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [3]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [3]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2, 2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [3, 2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [3, 4, 3]
# N-{P}-[ST]-{P} [2, 3, 4]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2, 2, 2]
# N-{P}-[ST]-{P} [2, 2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2, 2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2, 2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2, 2]
# N-{P}-[ST]-{P} [2, 2, 2]
# N-{P}-[ST]-{P} [2, 3]
# N-{P}-[ST]-{P} [2, 2, 2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# N-{P}-[ST]-{P} [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2]
# [RK](2)-x-[ST] [2, 2]
# [RK](2)-x-[ST] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2, 2, 2, 3]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2, 2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2, 2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2, 2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [4]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 3, 2]
# [ST]-x-[RK] [4]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2, 2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [4, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2, 2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [3]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [4]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x-[RK] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [4]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [4, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 2, 3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 4, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [4]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 3]
# [ST]-x(2)-[DE] [2, 2, 2, 3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 4]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 4]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 3, 2]
# [ST]-x(2)-[DE] [2, 3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 3]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 3]
# [ST]-x(2)-[DE] [2, 3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 4, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3, 2]
# [ST]-x(2)-[DE] [2, 2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [3]
# [ST]-x(2)-[DE] [2, 2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [ST]-x(2)-[DE] [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [3]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [3]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2, 2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2, 2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2, 2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# [RK]-x(2,3)-[DE]-x(2,3)-Y [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 5, 4, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3, 5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 6, 5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2, 2, 6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 4, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [6, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4, 2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# ...
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 3, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 3, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 4, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 4, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 3, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2, 2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2, 2, 5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [6]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 6, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 6, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 4, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3, 4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4, 5, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 3, 4, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3, 2, 2, 4, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4, 2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 5]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 4]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [2, 2]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# G-{EDRKHPFYW}-x(2)-[STAGCN]-{P} [3]
# x-G-[RK]-[RK] [2]
# x-G-[RK]-[RK] [2]
# x-G-[RK]-[RK] [2]
# L-x(6)-L-x(6)-L-x(6)-L [2]
# L-x(6)-L-x(6)-L-x(6)-L [2]
# L-x(6)-L-x(6)-L-x(6)-L [2]
# [KRQ]-[LIVMA]-x(2)-[GSTALIV]-{FYWPGDN}-x(2)-[LIVMSA]-x(4,9)-[LIVMF]-x-{PLH}-[LIVMSTA]-[GSTACIL]-{GPK}-{F}-x-[GANQRF]-[LIVMFY]-x(4,5)-[LFY]-x(3)-[FYIVA]-{FYWHCM}-{PGVI}-x(2)-[GSADENQKR]-x-[NSTAPKL]-[PARL] [2]
# R-x(2)-[LIVMT]-x(2,3)-[FWY]-[QNYDI]-x(8,13)-[LVESI]-x-P-C-[HAVMLC]-x(3)-[QMTLHD]-[FYWL]-x(0,1)-[LV] [2]
# R-x(2)-[LIVMT]-x(2,3)-[FWY]-[QNYDI]-x(8,13)-[LVESI]-x-P-C-[HAVMLC]-x(3)-[QMTLHD]-[FYWL]-x(0,1)-[LV] [2]
# R-x(2)-[LIVMT]-x(2,3)-[FWY]-[QNYDI]-x(8,13)-[LVESI]-x-P-C-[HAVMLC]-x(3)-[QMTLHD]-[FYWL]-x(0,1)-[LV] [2]
# R-x(2)-[LIVMT]-x(2,3)-[FWY]-[QNYDI]-x(8,13)-[LVESI]-x-P-C-[HAVMLC]-x(3)-[QMTLHD]-[FYWL]-x(0,1)-[LV] [2]
# R-x(2)-[LIVMT]-x(2,3)-[FWY]-[QNYDI]-x(8,13)-[LVESI]-x-P-C-[HAVMLC]-x(3)-[QMTLHD]-[FYWL]-x(0,1)-[LV] [2]
# P-x(0,2)-[GSTAN]-[DENQGAPK]-x-[LIVMFP]-[HT]-[LIVMYAC]-G-[HNTG]-[LIVMFYSTAGPC] [2]
# P-x(0,2)-[GSTAN]-[DENQGAPK]-x-[LIVMFP]-[HT]-[LIVMYAC]-G-[HNTG]-[LIVMFYSTAGPC] [2]
# [GA]-x(0,2)-[YSA]-x(0,1)-[VFY]-{SEDT}-C-x(1,2)-[PG]-x(0,1)-H-x(2,4)-[MQ] [2]
# [GA]-x(0,2)-[YSA]-x(0,1)-[VFY]-{SEDT}-C-x(1,2)-[PG]-x(0,1)-H-x(2,4)-[MQ] [2]
# [GA]-x(0,2)-[YSA]-x(0,1)-[VFY]-{SEDT}-C-x(1,2)-[PG]-x(0,1)-H-x(2,4)-[MQ] [2]
# [GA]-x(0,2)-[YSA]-x(0,1)-[VFY]-{SEDT}-C-x(1,2)-[PG]-x(0,1)-H-x(2,4)-[MQ] [2]
# [GA]-x(0,2)-[YSA]-x(0,1)-[VFY]-{SEDT}-C-x(1,2)-[PG]-x(0,1)-H-x(2,4)-[MQ] [2]
# [GA]-x(0,2)-[YSA]-x(0,1)-[VFY]-{SEDT}-C-x(1,2)-[PG]-x(0,1)-H-x(2,4)-[MQ] [2]
# [GA]-x(0,2)-[YSA]-x(0,1)-[VFY]-{SEDT}-C-x(1,2)-[PG]-x(0,1)-H-x(2,4)-[MQ] [2]
# [GA]-x(0,2)-[YSA]-x(0,1)-[VFY]-{SEDT}-C-x(1,2)-[PG]-x(0,1)-H-x(2,4)-[MQ] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [DENG]-{A}-[DENQGSTARK]-x(0,2)-[DENQARK]-[LIVFY]-{CP}-G-{C}-W-[FYWLRH]-{D}-[LIVMTA] [2]
# [SACVLG]-[AIPTV]-x(0,1)-K-[ADGS]-[DEN]-[GA]-Y-G-[HACILN]-[GD] [2]
# [FYVMT]-x(1,3)-[LIVMH]-[APNT]-[LIVM]-x(1,2)-[LIVM]-H-x-D-H-[GACH] [3]
# C-x(4,6)-[FYH]-x(5,10)-C-x(0,2)-C-x(2,3)-C-x(7,11)-C-x(4,6)-[DNEQSKP]-{PD}-{CP}-C [4]
# [GD]-x(0,10)-[FYWA]-x(0,1)-G-[LIVM]-x(0,2)-[LIVMFYD]-x(0,7)-G-[KN]-[NHW]-x(0,1)-G-[STARCV]-x(0,2)-[GD]-x(0,2)-[LY]-[FC] [2]
# [GSA]-x(2,6)-[LIVMSCP]-x-{N}-[LIVMF]-[DNS]-[LIVMCA]-G-G-G-[LIVMFY]-[GSTPCEQ] [2]
# [GSA]-x(2,6)-[LIVMSCP]-x-{N}-[LIVMF]-[DNS]-[LIVMCA]-G-G-G-[LIVMFY]-[GSTPCEQ] [2]
# [GSA]-x(2,6)-[LIVMSCP]-x-{N}-[LIVMF]-[DNS]-[LIVMCA]-G-G-G-[LIVMFY]-[GSTPCEQ] [2]
# [GSA]-x(2,6)-[LIVMSCP]-x-{N}-[LIVMF]-[DNS]-[LIVMCA]-G-G-G-[LIVMFY]-[GSTPCEQ] [2]

# %%
a = np.array(repeat_counts)

# %%
a.min(), a.max(), a.mean()
# Out:
# (2, 27, 4.094465372355839)

# %%
a.sum()
# Out:
# 28260
